# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.3.0
# Torchvision Version:  0.4.1a0+d94043a

# %%
# Define configurations for transfer learning

data_dir = '../../data'
model_name = 'resnet'

num_classes = 2
batch_size = 8

num_epochs = 15

# Flag for feature extracting. When False, we finetune the whole model,
# when True we only update the reshaped layer params
feature_extract = True

# %%
def train_model(model, dataloaders, criterion, )

# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import numpy as np

from classifier import Classifier
from optimizer import Optimizer
from dataset import DataSet

if __name__ == '__main__':

    data_dir = 'data'
    model_name = 'resnet'
    output_classes = 2
    feature_extract = True
    batch_size = 4
    num_epochs = 15

    resnetClassifier = Classifier(model_name, output_classes)
    model = resnetClassifier.initPretrainedModel(224)

    dataloaders, dataset_sizes, class_names = DataSet.initDataLoaders(data_dir, batch_size)
    data_transforms = DataSet.setUpDataLoaderTransformers()

    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in
                      ['train', 'val', 'test']}

    # Create training and validation dataloaders
    dataloaders_dict = {
        x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in
        ['train', 'val', 'test']}

    # Detect if we have a GPU available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    sgdOptimizer = Optimizer(device)
    optimizer_ft = sgdOptimizer.optimize(model, feature_extract, 0.001, 0.9)

    criterion = nn.CrossEntropyLoss()

    model, hist = resnetClassifier.train_model(model,
                                                criterion,
                                                optimizer_ft,
                                                dataloaders_dict,
                                                dataset_sizes)

    torch.save({
        'name': 'resnet_feature_extraction',
        'epoch': 15,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer_ft.state_dict(),
    }, './trainedModels/resnetFeatureExtraction.pt')

    # testing
    state = torch.load('./trainedModels/resnetFeatureExtraction.pt')
    model.load_state_dict(state['model_state_dict'])
    predictions = resnetClassifier.testModel(dataloaders_dict, model, class_names, dataset_sizes, batch_size=4)

    # save predicted values
    np.savetxt('./trainedModels/predictedLabelsResNet.csv', predictions, fmt='%s')
# Out:
# Initializing pretrained resnet 18...
# Params to learn:
# 	 fc.weight
# 	 fc.bias
# Epoch 0/14
# ----------
# train Loss: 0.1643 Acc: 0.9456
# val Loss: 0.4834 Acc: 0.9091
#
# Epoch 1/14
# ----------
# train Loss: 0.1270 Acc: 0.9545
# val Loss: 0.3179 Acc: 0.9236
#
# Epoch 2/14
# ----------
# train Loss: 0.1165 Acc: 0.9600
# val Loss: 0.2904 Acc: 0.9164
#
# Epoch 3/14
# ----------
# train Loss: 0.1140 Acc: 0.9636
# val Loss: 0.4831 Acc: 0.9164
#
# Epoch 4/14
# ----------
# train Loss: 0.1173 Acc: 0.9597
# val Loss: 0.2782 Acc: 0.9382
#
# Epoch 5/14
# ----------
# train Loss: 0.1081 Acc: 0.9631
# val Loss: 0.4577 Acc: 0.9127
#
# Epoch 6/14
# ----------
# train Loss: 0.1059 Acc: 0.9628
# val Loss: 0.3761 Acc: 0.9200
#
# Epoch 7/14
# ----------
# train Loss: 0.1019 Acc: 0.9664
# val Loss: 0.3612 Acc: 0.9236
#
# Epoch 8/14
# ----------
# train Loss: 0.1051 Acc: 0.9640
# val Loss: 0.3428 Acc: 0.9164
#
# Epoch 9/14
# ----------
# train Loss: 0.1042 Acc: 0.9674
# val Loss: 0.4280 Acc: 0.9164
#
# Epoch 10/14
# ----------
# train Loss: 0.1141 Acc: 0.9607
# val Loss: 0.3900 Acc: 0.9164
#
# Epoch 11/14
# ----------
# train Loss: 0.1031 Acc: 0.9658
# val Loss: 0.4215 Acc: 0.9200
#
# Epoch 12/14
# ----------
# train Loss: 0.1021 Acc: 0.9636
# val Loss: 0.3280 Acc: 0.9345
#
# Epoch 13/14
# ----------
# train Loss: 0.1039 Acc: 0.9647
# val Loss: 0.4083 Acc: 0.9164
#
# Epoch 14/14
# ----------
# train Loss: 0.1017 Acc: 0.9649
# val Loss: 0.3357 Acc: 0.9418
#
# Training complete in 149m 22s
# Best val Acc: 0.941818
# Accuracy of the network on the test images: 86 %

# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import numpy as np

from classifier import Classifier
from optimizer import Optimizer
from dataset import DataSet

if __name__ == '__main__':

    data_dir = 'data'
    model_name = 'resnet'
    output_classes = 2
    feature_extract = True
    batch_size = 4
    num_epochs = 15

    resnetClassifier = Classifier(model_name, output_classes)
    model = resnetClassifier.initPretrainedModel(224)

    dataloaders, dataset_sizes, class_names = DataSet.initDataLoaders(data_dir, batch_size)
    data_transforms = DataSet.setUpDataLoaderTransformers()

    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in
                      ['train', 'val', 'test']}

    # Create training and validation dataloaders
    dataloaders_dict = {
        x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in
        ['train', 'val', 'test']}

    # Detect if we have a GPU available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    sgdOptimizer = Optimizer(device)
    optimizer_ft = sgdOptimizer.optimize(model, feature_extract, 0.001, 0.9)

    criterion = nn.CrossEntropyLoss()

    model, hist = resnetClassifier.train_model(model,
                                                criterion,
                                                optimizer_ft,
                                                dataloaders_dict,
                                                dataset_sizes)

    torch.save({
        'name': 'resnet_feature_extraction_2',
        'epoch': 15,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer_ft.state_dict(),
    }, './trainedModels/resnetFeatureExtraction2.pt')

    # testing
    state = torch.load('./trainedModels/resnetFeatureExtraction2.pt')
    model.load_state_dict(state['model_state_dict'])
    predictions = resnetClassifier.testModel(dataloaders_dict, model, class_names, dataset_sizes, batch_size=4)

    # save predicted values
    np.savetxt('./trainedModels/predictedLabelsResNet2.csv', predictions, fmt='%s')
# Out:
# Initializing pretrained resnet 18...
# Params to learn:
# 	 fc.weight
# 	 fc.bias
# Epoch 0/14
# ----------
# train Loss: 0.1938 Acc: 0.9388
# val Loss: 0.4287 Acc: 0.8618
#
# Epoch 1/14
# ----------
# train Loss: 0.1530 Acc: 0.9471
# val Loss: 0.0902 Acc: 0.9673
#
# Epoch 2/14
# ----------
# train Loss: 0.1593 Acc: 0.9476
# val Loss: 0.2116 Acc: 0.9164
#
# Epoch 3/14
# ----------
# train Loss: 0.1560 Acc: 0.9496
# val Loss: 0.1485 Acc: 0.9345
#
# Epoch 4/14
# ----------
# train Loss: 0.1530 Acc: 0.9496
# val Loss: 0.1176 Acc: 0.9382
#
# Epoch 5/14
# ----------
# train Loss: 0.1523 Acc: 0.9508
# val Loss: 0.2444 Acc: 0.9164
#
# Epoch 6/14
# ----------
# train Loss: 0.1474 Acc: 0.9510
# val Loss: 0.1408 Acc: 0.9455
#
# Epoch 7/14
# ----------
# train Loss: 0.1565 Acc: 0.9488
# val Loss: 0.4150 Acc: 0.8945
#
# Epoch 8/14
# ----------
# train Loss: 0.1566 Acc: 0.9489
# val Loss: 0.0807 Acc: 0.9709
#
# Epoch 9/14
# ----------
# train Loss: 0.1453 Acc: 0.9516
# val Loss: 0.0545 Acc: 0.9891
#
# Epoch 10/14
# ----------
# train Loss: 0.1537 Acc: 0.9473
# val Loss: 0.1329 Acc: 0.9418
#
# Epoch 11/14
# ----------
# train Loss: 0.1451 Acc: 0.9549
# val Loss: 0.1164 Acc: 0.9418
#
# Epoch 12/14
# ----------
# train Loss: 0.1548 Acc: 0.9515
# val Loss: 0.0730 Acc: 0.9709
#
# Epoch 13/14
# ----------
# train Loss: 0.1510 Acc: 0.9509
# val Loss: 0.0719 Acc: 0.9709
#
# Epoch 14/14
# ----------
# train Loss: 0.1485 Acc: 0.9498
# val Loss: 0.0970 Acc: 0.9600
#
# Training complete in 177m 24s
# Best val Acc: 0.989091
# Accuracy of the network on the test images: 89 %
